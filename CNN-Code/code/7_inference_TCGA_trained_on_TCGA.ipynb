# %% [markdown]
# # Inference
# - Perform inference on TCGA test set using model trained on TCGA (use the weights saved in '../code/checkpoints_2').
# - Model is trained using gene expression programs as classes - Common, MITF-Low, OxPhos, Other.
# - Test notebook for script.
# - Script generates `0714_pred.csv`.
#
# #### Notes
# - Run pre-trained model on tile test set.
# - Test set contains all WSIs except those used for training.

# %% [markdown]
# ***
# ## Inference (test code for script)

# %%
import torch
import pandas as pd
import numpy as np
import os
from tqdm import tqdm

# %%
'Load metadata'

data_fld = '../data'
sub_fld = os.path.join(data_fld, 'TCGA_data')
path = os.path.join(sub_fld, 'tcga_wsi_meta.csv')
df_wsi = pd.read_csv(path, index_col=0)
path = os.path.join(sub_fld, 'tcga_tile_meta.csv')
df_tile = pd.read_csv(path)

home = os.getenv("HOME")
disk_path = os.path.join(home, 'disks')
tiles_path = os.path.join(disk_path, 'TCGA_tiles')

# %%
df_wsi.head(2)
# Out:
#                   clinical_sample_id   primary_tumor_type  CNA_data  \
# clinical_donor_id
# TCGA-3N-A9WC         TCGA-3N-A9WC-06  NON-ACRAL CUTANEOUS      True
# TCGA-3N-A9WD         TCGA-3N-A9WD-06  NON-ACRAL CUTANEOUS      True
#
#                    ABSOLUTE_purity rna_subtype  pigment_score  BetaCAT  P53  \
# clinical_donor_id
# TCGA-3N-A9WC                  0.55      Common            NaN        0    0
# TCGA-3N-A9WD                  0.45      Common            NaN        0    1
#
#                    PTEN  APC
# clinical_donor_id
# TCGA-3N-A9WC          0    1
# TCGA-3N-A9WD          0    0

# %%
df_tile.head(2)
# Out:
#                              Unnamed: 0  x_tile_coord  y_tile_coord  \
# wsi_id
# TCGA-EE-A3JD-01Z-00-DX1.svs           2             1             8
# TCGA-D3-A3CB-06Z-00-DX1.svs           4             0             5
#
#                             clinical_donor_id  \
# wsi_id
# TCGA-EE-A3JD-01Z-00-DX1.svs      TCGA-EE-A3JD
# TCGA-D3-A3CB-06Z-00-DX1.svs      TCGA-D3-A3CB
#
#                                                                       wsi_name  \
# wsi_id
# TCGA-EE-A3JD-01Z-00-DX1.svs  TCGA-EE-A3JD-01Z-00-DX1.D4E5B644-C7EF-442D-91F...
# TCGA-D3-A3CB-06Z-00-DX1.svs  TCGA-D3-A3CB-06Z-00-DX1.9862D604-C9E7-44BE-99E...
#
#                             clinical_sample_id   primary_tumor_type  CNA_data  \
# wsi_id
# TCGA-EE-A3JD-01Z-00-DX1.svs    TCGA-EE-A3JD-06  NON-ACRAL CUTANEOUS      True
# TCGA-D3-A3CB-06Z-00-DX1.svs    TCGA-D3-A3CB-06  NON-ACRAL CUTANEOUS      True
#
#                              ABSOLUTE_purity rna_subtype  ...     PTEN_prob  \
# wsi_id                                                    ...
# TCGA-EE-A3JD-01Z-00-DX1.svs             0.26    MITF-Low  ...  1.858032e-14
# TCGA-D3-A3CB-06Z-00-DX1.svs             0.37      Common  ...  1.249998e-01
#
#                              APC_prob  APC_BC  OxPhos APC_OxPhos  \
# wsi_id
# TCGA-EE-A3JD-01Z-00-DX1.svs       1.0       0   False      False
# TCGA-D3-A3CB-06Z-00-DX1.svs       1.0       0   False      False
#
#                              APC_BC_OxPhos  P53_MITF  P53_Co  P53_MITF_Co  \
# wsi_id
# TCGA-EE-A3JD-01Z-00-DX1.svs          False      True    True         True
# TCGA-D3-A3CB-06Z-00-DX1.svs          False     False    True         True
#
#                              MITF_Co
# wsi_id
# TCGA-EE-A3JD-01Z-00-DX1.svs     True
# TCGA-D3-A3CB-06Z-00-DX1.svs     True
#
# [2 rows x 35 columns]

# %% [markdown]
# In importing this model check that:
# - it loads the ORIGINAL weights of the patchwise network (`/weights_pw1.pth` even though it says it fails).
# - it loads the SAURABH weights for the image wise network (`'/weights_iw_h2gnew_trn1.pth`)

# %%
from src import *
import sys
sys.argv[1:] = []
args = ModelOptions().parse()
# Out:
# ------------ Options -------------
# batch_size: 64
# beta1: 0.9
# beta2: 0.999
# channels: 1
# checkpoints_path: ./checkpoints_0709
# cuda: True
# dataset_path: /home/sparkar/disks/2021_7_9_set
# debug: False
# ensemble: 1
# epochs: 50
# gpu_ids: 0
# log_interval: 5
# lr: 0.0001
# network: 0
# no_cuda: False
# patch_stride: 256
# seed: 1
# test_batch_size: 64
# testset_path: ./home/sparkar/disks/2021_7_9_set/test
# -------------- End ----------------

# %%
pw_network = PatchWiseNetwork(args.channels)
iw_network = ImageWiseNetwork(args.channels)
im_model = ImageWiseModel(args, iw_network, pw_network)
# Out:
# Loading "image-wise" model...
# Loading "patch-wise" model...

# %%
img_fld = tiles_path
# os.listdir(img_fld)

# %%
# Use for checking few rows
# df_out = df_tile.reset_index().sample(n=10)
df_out = df_tile.reset_index()

# %%
df_out
# Out:
#                             wsi_id  Unnamed: 0  x_tile_coord  y_tile_coord  \
# 0      TCGA-EE-A3JD-01Z-00-DX1.svs           2             1             8
# 1      TCGA-D3-A3CB-06Z-00-DX1.svs           4             0             5
# 2      TCGA-EE-A2MK-01Z-00-DX1.svs           5             8             6
# 3      TCGA-ER-A2NF-01Z-00-DX1.svs           7             4             9
# 4      TCGA-EE-A2MI-01Z-00-DX1.svs           8             9             6
# ...                            ...         ...           ...           ...
# 19916  TCGA-D3-A2J9-06Z-00-DX1.svs       21989             1             5
# 19917  TCGA-BF-A5EO-01Z-00-DX1.svs       21990            13             7
# 19918  TCGA-EE-A20C-01Z-00-DX1.svs       21991             7             3
# 19919  TCGA-ER-A2NG-01Z-00-DX1.svs       21992             2             4
# 19920  TCGA-EE-A29N-01Z-00-DX1.svs       21994             7             5
#
#       clinical_donor_id                                           wsi_name  \
# 0          TCGA-EE-A3JD  TCGA-EE-A3JD-01Z-00-DX1.D4E5B644-C7EF-442D-91F...
# 1          TCGA-D3-A3CB  TCGA-D3-A3CB-06Z-00-DX1.9862D604-C9E7-44BE-99E...
# 2          TCGA-EE-A2MK  TCGA-EE-A2MK-01Z-00-DX1.3A8F8407-BA89-46E6-959...
# 3          TCGA-ER-A2NF  TCGA-ER-A2NF-01Z-00-DX1.1468DD2D-6AC8-4657-A02...
# 4          TCGA-EE-A2MI  TCGA-EE-A2MI-01Z-00-DX1.1C56D0A7-3FA7-49A6-BBC...
# ...                 ...                                                ...
# 19916      TCGA-D3-A2J9  TCGA-D3-A2J9-06Z-00-DX1.5526CFD6-96AB-49F8-B88...
# 19917      TCGA-BF-A5EO  TCGA-BF-A5EO-01Z-00-DX1.1BA74189-485E-4ABF-831...
# 19918      TCGA-EE-A20C  TCGA-EE-A20C-01Z-00-DX1.48BAD79E-DFC8-44A7-92F...
# 19919      TCGA-ER-A2NG  TCGA-ER-A2NG-01Z-00-DX1.35B12E55-502A-4B87-A68...
# 19920      TCGA-EE-A29N  TCGA-EE-A29N-01Z-00-DX1.9842217A-23B9-40CA-91C...
#
#       clinical_sample_id   primary_tumor_type  CNA_data  ABSOLUTE_purity  ...  \
# 0        TCGA-EE-A3JD-06  NON-ACRAL CUTANEOUS      True             0.26  ...
# 1        TCGA-D3-A3CB-06  NON-ACRAL CUTANEOUS      True             0.37  ...
# 2        TCGA-EE-A2MK-06  NON-ACRAL CUTANEOUS      True             0.76  ...
# 3        TCGA-ER-A2NF-01  NON-ACRAL CUTANEOUS      True             0.58  ...
# 4        TCGA-EE-A2MI-06  NON-ACRAL CUTANEOUS      True             0.66  ...
# ...                  ...                  ...       ...              ...  ...
# 19916    TCGA-D3-A2J9-06  NON-ACRAL CUTANEOUS      True             0.59  ...
# 19917    TCGA-BF-A5EO-01  NON-ACRAL CUTANEOUS      True             0.61  ...
# 19918    TCGA-EE-A20C-06  NON-ACRAL CUTANEOUS      True             0.89  ...
# 19919    TCGA-ER-A2NG-06  NON-ACRAL CUTANEOUS      True             0.49  ...
# 19920    TCGA-EE-A29N-06  NON-ACRAL CUTANEOUS      True             0.39  ...
#
#           PTEN_prob  APC_prob  APC_BC  OxPhos  APC_OxPhos APC_BC_OxPhos  \
# 0      1.858032e-14  1.000000       0   False       False         False
# 1      1.249998e-01  1.000000       0   False       False         False
# 2      1.000000e+00  1.000000       0   False       False         False
# 3      4.795476e-02  0.999850       0   False       False         False
# 4      1.546927e-17  1.000000       0   False       False         False
# ...             ...       ...     ...     ...         ...           ...
# 19916  3.670689e-01  0.999996       0   False       False         False
# 19917  8.264103e-01  0.766232       0    True        True          True
# 19918  7.886669e-01  0.011984       0   False       False         False
# 19919  1.194280e-01  0.029790       0   False       False         False
# 19920  1.000000e+00  1.000000       0   False       False         False
#
#        P53_MITF  P53_Co  P53_MITF_Co  MITF_Co
# 0          True    True         True     True
# 1         False    True         True     True
# 2         False    True         True     True
# 3         False    True         True     True
# 4          True   False         True     True
# ...         ...     ...          ...      ...
# 19916     False    True         True     True
# 19917     False   False        False    False
# 19918     False    True         True     True
# 19919     False    True         True     True
# 19920     False    True         True     True
#
# [19921 rows x 36 columns]

# %%
LABELS = ['Common', 'MITF-Low', 'OxPhos', 'Other']

# %%
preds = []
for ix, entry in tqdm(df_out.iterrows()):
    file = entry.wsi_id.split('.svs')[0] + '_' + str(entry.x_tile_coord) + '_' + str(entry.y_tile_coord) + '.png'
    tile_path = os.path.join(img_fld, file)
    assert os.path.isfile(tile_path)
    [[pred, conf, file]], output = im_model.test(tile_path, ensemble=args.ensemble == 1, verbose=False)
    softmax_res = torch.sum(np.exp(output.cpu().data), dim=0)
    probs = np.array(softmax_res / torch.sum(softmax_res))
    preds.append(probs)
# Out:
# 19921it [7:00:07,  1.27s/it]

# %%
df_out['pred_prob'] = preds

# %%
df_out[['wsi_id','x_tile_coord','y_tile_coord','clinical_donor_id','wsi_name','clinical_sample_id','primary_tumor_type','CNA_data','ABSOLUTE_purity','rna_subtype','BetaCAT','P53','PTEN','APC', 'pred_prob']]
# Out:
#                             wsi_id  x_tile_coord  y_tile_coord  \
# 15236  TCGA-D3-A2J8-06Z-00-DX1.svs             7             9
# 13737  TCGA-D3-A1QA-07Z-00-DX1.svs             5             4
# 14691  TCGA-GF-A6C8-06Z-00-DX1.svs             7             7
# 13293  TCGA-RP-A694-01Z-00-DX1.svs             1             0
# 11138  TCGA-GN-A8LK-06Z-00-DX1.svs             7             1
# 9500   TCGA-FS-A1ZD-06Z-00-DX2.svs             7             2
# 16438  TCGA-GN-A264-01Z-00-DX1.svs             4             3
# 1717   TCGA-EE-A20F-01Z-00-DX1.svs             6             4
# 17957  TCGA-GN-A4U8-06Z-00-DX1.svs             0             5
# 7322   TCGA-DA-A1HV-01Z-00-DX1.svs            13             3
#
#       clinical_donor_id                                           wsi_name  \
# 15236      TCGA-D3-A2J8  TCGA-D3-A2J8-06Z-00-DX1.5FB8E98F-EAFF-491F-856...
# 13737      TCGA-D3-A1QA  TCGA-D3-A1QA-07Z-00-DX1.FF80DD52-540E-4378-BAC...
# 14691      TCGA-GF-A6C8  TCGA-GF-A6C8-06Z-00-DX1.9388CB1A-BF64-4CE8-AAC...
# 13293      TCGA-RP-A694  TCGA-RP-A694-01Z-00-DX1.31B4F597-0CDA-4A3B-B34...
# 11138      TCGA-GN-A8LK  TCGA-GN-A8LK-06Z-00-DX1.C529E9FC-003A-4E7D-A42...
# 9500       TCGA-FS-A1ZD  TCGA-FS-A1ZD-06Z-00-DX2.B2BF872D-1690-49FC-A8E...
# 16438      TCGA-GN-A264  TCGA-GN-A264-01Z-00-DX1.2C02EEF5-92DF-4DAF-BDE...
# 1717       TCGA-EE-A20F  TCGA-EE-A20F-01Z-00-DX1.78401458-3FDA-4D9D-856...
# 17957      TCGA-GN-A4U8  TCGA-GN-A4U8-06Z-00-DX1.BD0E3D01-7FE9-40B6-9C8...
# 7322       TCGA-DA-A1HV  TCGA-DA-A1HV-01Z-00-DX1.1206FAE0-BC4B-494B-923...
#
#       clinical_sample_id   primary_tumor_type  CNA_data  ABSOLUTE_purity  \
# 15236    TCGA-D3-A2J8-06  NON-ACRAL CUTANEOUS      True             0.29
# 13737    TCGA-D3-A1QA-06  NON-ACRAL CUTANEOUS      True             0.92
# 14691    TCGA-GF-A6C8-06  NON-ACRAL CUTANEOUS      True             0.68
# 13293    TCGA-RP-A694-06  NON-ACRAL CUTANEOUS      True             0.65
# 11138    TCGA-GN-A8LK-06  NON-ACRAL CUTANEOUS      True             0.95
# 9500     TCGA-FS-A1ZD-06  NON-ACRAL CUTANEOUS      True             0.87
# 16438    TCGA-GN-A264-06  NON-ACRAL CUTANEOUS      True             0.83
# 1717     TCGA-EE-A20F-06  NON-ACRAL CUTANEOUS      True             0.70
# 17957    TCGA-GN-A4U8-06  NON-ACRAL CUTANEOUS      True             0.52
# 7322     TCGA-DA-A1HV-06  NON-ACRAL CUTANEOUS      True             0.65
#
#       rna_subtype  BetaCAT  P53  PTEN  APC  \
# 15236    MITF-Low        0    0     1    0
# 13737      Common        0    1     0    0
# 14691      Common        0    1     0    0
# 13293      Common        0    0     1    0
# 11138      OxPhos        0    1     0    1
# 9500     MITF-Low        0    0     1    0
# 16438      Common        0    0     0    0
# 1717       Common        0    0     1    0
# 17957      Common        0    0     1    0
# 7322       Common        0    1     0    0
#
#                                                pred_prob
# 15236  [0.024246216, 0.37138513, 0.03001649, 0.57435215]
# 13737  [0.10113474, 0.012738679, 0.8591208, 0.027005829]
# 14691    [0.123553514, 0.3047312, 0.24140185, 0.3303135]
# 13293    [0.12726061, 0.05458201, 0.62833977, 0.1898176]
# 11138  [0.0050443173, 1.7647683e-06, 0.9948322, 0.000...
# 9500    [0.21602325, 0.44300774, 0.15697816, 0.18399087]
# 16438  [0.103794605, 0.47655484, 0.29156864, 0.12808193]
# 1717   [0.9531235, 0.04120145, 2.4798052e-05, 0.00565...
# 17957  [0.0061760247, 0.014887752, 0.10771593, 0.8712...
# 7322    [0.37403658, 0.36738807, 0.07040305, 0.18817234]

# %%
# ne salvo uno per fare test veloci
df_out.to_csv('../results/0714_pred.csv')
